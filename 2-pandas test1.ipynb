# %%
import pandas as pd

# %%
df=pd.read_csv("covid_vaccine_statewise.csv")
df.head()
# Out:
#    Updated On  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %%
df.shape
# Out:
# (7845, 24)

# %%
df.sample(frac=0.20)
# Out:
#       Updated On             State  Total Doses Administered   Sessions  \
# 2788  16/02/2021  Himachal Pradesh                   84718.0     2292.0
# 4501  05/03/2021       Maharashtra                 1479034.0    46743.0
# 4043  30/01/2021       Lakshadweep                     807.0       19.0
# 4676  27/01/2021           Manipur                    1873.0       95.0
# 6180  16/02/2021         Rajasthan                  626481.0    13994.0
# ...          ...               ...                       ...        ...
# 5361  17/03/2021          Nagaland                   56257.0     6960.0
# 1247  22/07/2021             Bihar                21652372.0   662066.0
# 3710  01/05/2021            Kerala                 7425416.0    69210.0
# 7525  30/04/2021       Uttarakhand                 2079214.0   129050.0
# 1220  25/06/2021             Bihar                15512516.0  2273753.0
#
#        Sites   First Dose Administered  Second Dose Administered  \
# ...

# %%
df.loc[df.State=='Karnataka']
# Out:
#       Updated On      State  Total Doses Administered  Sessions   Sites   \
# 3393  16/01/2021  Karnataka                    3810.0     256.0    235.0
# 3394  17/01/2021  Karnataka                    4506.0    1385.0   1139.0
# 3395  18/01/2021  Karnataka                   14755.0    1999.0   1502.0
# 3396  19/01/2021  Karnataka                   25142.0    2788.0   1993.0
# 3397  20/01/2021  Karnataka                   36705.0    3687.0   2517.0
# ...          ...        ...                       ...       ...      ...
# 3600  11/08/2021  Karnataka                       NaN       NaN      NaN
# 3601  12/08/2021  Karnataka                       NaN       NaN      NaN
# 3602  13/08/2021  Karnataka                       NaN       NaN      NaN
# 3603  14/08/2021  Karnataka                       NaN       NaN      NaN
# 3604  15/08/2021  Karnataka                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# ...

# %%
df.loc[df.State == "Karnataka"," Covaxin (Doses Administered)"].sum()
# Out:
# 260352181.0

# %%
df.loc[df.State=='Karnataka'].sum()
# Out:
# Updated On                             16/01/202117/01/202118/01/202119/01/202120/01/...
# State                                  KarnatakaKarnatakaKarnatakaKarnatakaKarnatakaK...
# Total Doses Administered                                                    2300517146.0
# Sessions                                                                     229117520.0
#  Sites                                                                          992413.0
# First Dose Administered                                                     1873329968.0
# Second Dose Administered                                                     427187178.0
# Male (Doses Administered)                                                   1061166867.0
# Female (Doses Administered)                                                 1059022410.0
# Transgender (Doses Administered)                                                335335.0
# ...

# %%
df.loc[df.State == "Karnataka","Male (Doses Administered)"].sum()
# Out:
# 1061166867.0

# %%
df.loc[df.State == "Karnataka","Female (Doses Administered)"].sum()
# Out:
# 1059022410.0

# %%
df.groupby('State')["Male (Doses Administered)","Female (Doses Administered)"].sum()
# Out:
# C:\Users\vamsh\AppData\Local\Temp\ipykernel_24668\2257615587.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('State')["Male (Doses Administered)","Female (Doses Administered)"].sum()
#                                           Male (Doses Administered)  \
# State
# Andaman and Nicobar Islands                            1.045375e+07
# Andhra Pradesh                                         6.776694e+08
# Arunachal Pradesh                                      3.061580e+07
# Assam                                                  3.557939e+08
# Bihar                                                  8.693946e+08
# Chandigarh                                             2.920781e+07
# Chhattisgarh                                           4.381651e+08
# Dadra and Nagar Haveli and Daman and Diu               2.378859e+07
# Delhi                                                  4.239074e+08
# ...
