# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("income.csv")
df.head()
# Out:
#   Index       State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 0     A     Alabama  1296530  1317711  1118631  1492583  1107408  1440134
# 1     A      Alaska  1170302  1960378  1818085  1447852  1861639  1465841
# 2     A     Arizona  1742027  1968140  1377583  1782199  1102568  1109382
# 3     A    Arkansas  1485531  1994927  1119299  1947979  1669191  1801213
# 4     C  California  1685349  1675807  1889570  1480280  1735069  1812546
#
#      Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 0  1945229  1944173  1237582  1440756  1186741  1852841  1558906  1916661
# 1  1551826  1436541  1629616  1230866  1512804  1985302  1580394  1979143
# 2  1752886  1554330  1300521  1130709  1907284  1363279  1525866  1647724
# 3  1188104  1628980  1669295  1928238  1216675  1591896  1360959  1329341
# 4  1487315  1663809  1624509  1639670  1921845  1156536  1388461  1644607

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
sample_df=pd.DataFrame({'a':[1,2,3],'b':[4,5,6]},index=[1,2,3])
print(sample_df)
# Out:
#    a  b
# 1  1  4
# 2  2  5
# 3  3  6

# %%
df.sample(frac=0.10)
# Out:
#    Index          State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 39     R   Rhode Island  1501744  1942942  1266657  1961923  1835983  1234040
# 45     V        Vermont  1146902  1832249  1492704  1579265  1332048  1563537
# 48     W  West Virginia  1677347  1380662  1176100  1888948  1922085  1740826
# 42     T      Tennessee  1811867  1485909  1974179  1157059  1786132  1399191
# 0      A        Alabama  1296530  1317711  1118631  1492583  1107408  1440134
#
#       Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 39  1151409  1993136  1983569  1781016  1909119  1531212  1990412  1611730
# 45  1123567  1618583  1326369  1792600  1714960  1146278  1282790  1565924
# 48  1238174  1539322  1539603  1872519  1462137  1683127  1204344  1198791
# 42  1826406  1326460  1231739  1469785  1849041  1560887  1349173  1162164
# 0   1945229  1944173  1237582  1440756  1186741  1852841  1558906  1916661

# %%
df.dtypes
# Out:
# Index    object
# State    object
# Y2002     int64
# Y2003     int64
# Y2004     int64
# Y2005     int64
# Y2006     int64
# Y2007     int64
# Y2008     int64
# Y2009     int64
# Y2010     int64
# Y2011     int64
# Y2012     int64
# Y2013     int64
# Y2014     int64
# Y2015     int64
# dtype: object

# %%
df.shape
# Out:
# (51, 16)

# %%
df.iloc[:4]
# Out:
#   Index     State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 0     A   Alabama  1296530  1317711  1118631  1492583  1107408  1440134
# 1     A    Alaska  1170302  1960378  1818085  1447852  1861639  1465841
# 2     A   Arizona  1742027  1968140  1377583  1782199  1102568  1109382
# 3     A  Arkansas  1485531  1994927  1119299  1947979  1669191  1801213
#
#      Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 0  1945229  1944173  1237582  1440756  1186741  1852841  1558906  1916661
# 1  1551826  1436541  1629616  1230866  1512804  1985302  1580394  1979143
# 2  1752886  1554330  1300521  1130709  1907284  1363279  1525866  1647724
# 3  1188104  1628980  1669295  1928238  1216675  1591896  1360959  1329341

# %%
df.iloc[:,:2]
# Out:
#    Index                 State
# 0      A               Alabama
# 1      A                Alaska
# 2      A               Arizona
# 3      A              Arkansas
# 4      C            California
# 5      C              Colorado
# 6      C           Connecticut
# 7      D              Delaware
# 8      D  District of Columbia
# 9      F               Florida
# 10     G               Georgia
# 11     H                Hawaii
# 12     I                 Idaho
# 13     I              Illinois
# 14     I               Indiana
# 15     I                  Iowa
# 16     K                Kansas
# 17     K              Kentucky
# 18     L             Louisiana
# 19     M                 Maine
# 20     M              Maryland
# 21     M         Massachusetts
# 22     M              Michigan
# 23     M             Minnesota
# 24     M           Mississippi
# 25     M              Missouri
# 26     M               Montana
# 27     N              Nebraska
# 28     N                Nevada
# ...

# %%
df.loc[:,"Index":"State"]
# Out:
#    Index                 State
# 0      A               Alabama
# 1      A                Alaska
# 2      A               Arizona
# 3      A              Arkansas
# 4      C            California
# 5      C              Colorado
# 6      C           Connecticut
# 7      D              Delaware
# 8      D  District of Columbia
# 9      F               Florida
# 10     G               Georgia
# 11     H                Hawaii
# 12     I                 Idaho
# 13     I              Illinois
# 14     I               Indiana
# 15     I                  Iowa
# 16     K                Kansas
# 17     K              Kentucky
# 18     L             Louisiana
# 19     M                 Maine
# 20     M              Maryland
# 21     M         Massachusetts
# 22     M              Michigan
# 23     M             Minnesota
# 24     M           Mississippi
# 25     M              Missouri
# 26     M               Montana
# 27     N              Nebraska
# 28     N                Nevada
# ...

# %%
df.sort_values('Y2002')
# Out:
#    Index                 State    Y2002    Y2003    Y2004    Y2005    Y2006  \
# 8      D  District of Columbia  1111437  1993741  1374643  1827949  1803852
# 46     V              Virginia  1134317  1163996  1891068  1853855  1708715
# 45     V               Vermont  1146902  1832249  1492704  1579265  1332048
# 41     S          South Dakota  1159037  1150689  1660148  1417141  1418586
# 1      A                Alaska  1170302  1960378  1818085  1447852  1861639
# 36     O              Oklahoma  1173918  1334639  1663622  1798714  1312574
# 25     M              Missouri  1221316  1858368  1773451  1573967  1374863
# 22     M              Michigan  1295635  1149931  1601027  1340716  1729449
# 0      A               Alabama  1296530  1317711  1118631  1492583  1107408
# 38     P          Pennsylvania  1320191  1446723  1218591  1122030  1971479
# 7      D              Delaware  1330403  1268673  1706751  1403759  1441351
# ...

# %%
df.describe()
# Out:
#               Y2002         Y2003         Y2004         Y2005         Y2006  \
# count  5.100000e+01  5.100000e+01  5.100000e+01  5.100000e+01  5.100000e+01
# mean   1.566034e+06  1.509193e+06  1.540555e+06  1.522064e+06  1.530969e+06
# std    2.464425e+05  2.641092e+05  2.813872e+05  2.671748e+05  2.505603e+05
# min    1.111437e+06  1.110625e+06  1.118631e+06  1.122030e+06  1.102568e+06
# 25%    1.374180e+06  1.292390e+06  1.268292e+06  1.267340e+06  1.337236e+06
# 50%    1.584734e+06  1.485909e+06  1.522230e+06  1.480280e+06  1.531641e+06
# 75%    1.776054e+06  1.686698e+06  1.808109e+06  1.778170e+06  1.732259e+06
# max    1.983285e+06  1.994927e+06  1.979395e+06  1.990062e+06  1.985692e+06
#
#               Y2007         Y2008         Y2009         Y2010         Y2011  \
# count  5.100000e+01  5.100000e+01  5.100000e+01  5.100000e+01  5.100000e+01
# mean   1.553219e+06  1.538398e+06  1.658519e+06  1.504108e+06  1.574968e+06
# ...

# %%
df.groupby('Index')['Y2002','Y2004'].max()
# Out:
# C:\Users\vamsh\AppData\Local\Temp\ipykernel_27600\1709991045.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Index')['Y2002','Y2004'].max()
#          Y2002    Y2004
# Index
# A      1742027  1818085
# C      1685349  1889570
# D      1330403  1706751
# F      1964626  1419738
# G      1929009  1810773
# H      1461570  1213993
# I      1776918  1739154
# K      1813878  1800760
# L      1584734  1868456
# M      1983285  1903907
# N      1885081  1935991
# O      1802132  1805445
# P      1320191  1218591
# R      1501744  1266657
# S      1631522  1660148
# T      1811867  1974179
# U      1771096  1979395
# V      1146902  1891068
# W      1977749  1289663

# %%
df.groupby("Index")['Y2003','Y2004'].agg(['mean','min'])
# Out:
# C:\Users\vamsh\AppData\Local\Temp\ipykernel_27600\2577801880.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby("Index")['Y2003','Y2004'].agg(['mean','min'])
#              Y2003                  Y2004
#               mean      min          mean      min
# Index
# A      1810289.000  1317711  1.358400e+06  1118631
# C      1595708.000  1232844  1.652556e+06  1181949
# D      1631207.000  1268673  1.540697e+06  1374643
# F      1468852.000  1468852  1.419738e+06  1419738
# G      1541565.000  1541565  1.810773e+06  1810773
# H      1200280.000  1200280  1.213993e+06  1213993
# I      1536164.500  1438538  1.519619e+06  1269927
# K      1369773.000  1290700  1.661495e+06  1522230
# L      1110625.000  1110625  1.868456e+06  1868456
# M      1535717.625  1149931  1.615166e+06  1208496
# N      1382499.625  1114500  1.477538e+06  1119707
# O      1569934.000  1334639  1.636818e+06  1441386
# ...
